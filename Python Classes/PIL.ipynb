# %% [markdown]
# # PIL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from PIL import Image
# Creates new image 
im_new = Image.new('RGB', (200,200))
im_new.show()

# %%
im = Image.open('RGBA.jpg')
print(im.size )
print(im.format)
print(im.mode)
print(im.show())
# Out:
# (1920, 1200)
# JPEG
# RGB
# None

# %%
# we can also create a new image by cropping a part of a given image:
im.crop((w1,h1,w2,h2))

# %%
im = Image.open('RGBA.jpg')
im2 = im.crop((100,100,300,400))
im2.show()

# %%
im3 = im.resize((300,200))  # Width, height
>>> im3.save('resized.jpg')

# %%
#Here is our first function with this property: im.paste(im2, (x,y)) pastes one image (im2) into the first image (im1) starting at the top left coordinates (x,y).
#Note that the second image must fit in the first image starting with these coordinates.

im = Image.open('RGBA.jpg')
im1.size 
im = Image.new('RGB', (600, 396*2))
im.paste( im1, (0,0))
im.show()
im.paste( im1, (0, 396))
im.show()

# %%
im = Image.open('RGBA.jpg')
r, g, b = im.split()
im = Image.merge("RGB", (b, g, r))
im.show()

# %%
region = region.transpose(Image.Transpose.ROTATE_180)
im.paste(region, box)

# %%
import os

# %%
for jpg in os.listdir('.'):
    if jpg.endswith('jpg'):
        print(jpg)
        fn, text = os.path.splitext(jpg)
        print(fn,',', text)
# Out:
# RGBA.jpg
# RGBA , .jpg
